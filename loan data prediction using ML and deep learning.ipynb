# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train_loan_data.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Gender"].fillna( method ='ffill', inplace = True)

# %%
df["Married"].fillna( method ='ffill', inplace = True)

# %%
df["Self_Employed"].fillna( method ='ffill', inplace = True)

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(value=146)

# %%
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(value=360)

# %%
df.loc[df.Dependents == "3+", "Dependents"] = "3"
df['Credit_History'] = df['Credit_History'].fillna(value=1)

# %%
df["Dependents"].fillna( method ='ffill', inplace = True)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.397394        342.410423
# std        6109.041673        2926.248369   84.037503         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes          3      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
from sklearn import preprocessing

# %%
label_encoder=preprocessing.LabelEncoder()
df['Gender']= label_encoder.fit_transform(df['Gender']) 
df['Married']= label_encoder.fit_transform(df['Married']) 
df['Education']= label_encoder.fit_transform(df['Education']) 
df['Education']= label_encoder.fit_transform(df['Education'])
df['Self_Employed']= label_encoder.fit_transform(df['Self_Employed'])
df['Property_Area']= label_encoder.fit_transform(df['Property_Area'])
df['Loan_Status']= label_encoder.fit_transform(df['Loan_Status'])

# %%
df.head(20)
# Out:
#      Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0   LP001002       1        0          0          0              0
# 1   LP001003       1        1          1          0              0
# 2   LP001005       1        1          0          0              1
# 3   LP001006       1        1          0          1              0
# 4   LP001008       1        0          0          0              0
# 5   LP001011       1        1          2          0              1
# 6   LP001013       1        1          0          1              0
# 7   LP001014       1        1          3          0              0
# 8   LP001018       1        1          2          0              0
# 9   LP001020       1        1          1          0              0
# 10  LP001024       1        1          2          0              0
# 11  LP001027       1        1          2          0              0
# 12  LP001028       1        1          2          0              0
# ...

# %%
x=df.iloc[:,1:-1].values

# %%
y=df.iloc[:,-1].values

# %%
x.shape
# Out:
# (614, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver= 'lbfgs', max_iter = 500) 
model.fit(x, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
dft=pd.read_csv('loan_data.csv')

# %%
dft.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
dft.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dft["Gender"].fillna( method ='ffill', inplace = True)
dft.loc[dft.Dependents == "3+", "Dependents"] = "3"
dft["Dependents"].fillna( method ='ffill', inplace = True)
dft["Self_Employed"].fillna( method ='ffill', inplace = True)
dft['LoanAmount'] = dft['LoanAmount'].fillna(value=136)
dft['Loan_Amount_Term'] = dft['Loan_Amount_Term'].fillna(value=360)
dft['Credit_History'] = dft['Credit_History'].fillna(value=1)

# %%
dft['Gender']= label_encoder.fit_transform(dft['Gender']) 
dft['Married']= label_encoder.fit_transform(dft['Married']) 
dft['Education']= label_encoder.fit_transform(dft['Education']) 
dft['Education']= label_encoder.fit_transform(dft['Education'])
dft['Self_Employed']= label_encoder.fit_transform(dft['Self_Employed'])
dft['Property_Area']= label_encoder.fit_transform(dft['Property_Area'])

# %%
dft
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          3          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
testdata=dft.iloc[:,1:].values

# %%
testdata
# Out:
# array([[1, 1, '0', ..., 360.0, 1.0, 2],
#        [1, 1, '1', ..., 360.0, 1.0, 2],
#        [1, 1, '2', ..., 360.0, 1.0, 2],
#        ...,
#        [1, 0, '0', ..., 360.0, 1.0, 1],
#        [1, 1, '0', ..., 360.0, 1.0, 0],
#        [1, 0, '0', ..., 180.0, 1.0, 0]], dtype=object)

# %%
y_predict = model.predict(testdata)

# %% [markdown]
# # ANN

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'epochs': [100, 500],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Epoch 1/100
# 441/441 [==============================] - 1s 2ms/step - loss: 0.6911 - accuracy: 0.7029
# Epoch 2/100
# 441/441 [==============================] - 0s 106us/step - loss: 0.6862 - accuracy: 0.7029
# Epoch 3/100
# 441/441 [==============================] - 0s 106us/step - loss: 0.6793 - accuracy: 0.7029
# Epoch 4/100
# 441/441 [==============================] - 0s 121us/step - loss: 0.6686 - accuracy: 0.7029
# Epoch 5/100
# 441/441 [==============================] - 0s 106us/step - loss: 0.6530 - accuracy: 0.7029
# Epoch 6/100
# 441/441 [==============================] - 0s 86us/step - loss: 0.6324 - accuracy: 0.7029
# Epoch 7/100
# 441/441 [==============================] - 0s 106us/step - loss: 0.6079 - accuracy: 0.7029
# Epoch 8/100
# 441/441 [==============================] - 0s 121us/step - loss: 0.5844 - accuracy: 0.7029
# Epoch 9/100
# 441/441 [==============================] - 0s 106us/step - loss: 0.5639 - accuracy: 0.7029
# Epoch 10/100
# ...

# %%
best_parameters
# Out:
# {'batch_size': 32, 'epochs': 100, 'optimizer': 'adam'}

# %%
best_accuracy
# Out:
# 0.8066530612244897
